# %% [markdown]
# ## ANALYSIS

# %%
## -----------IMPORT LIBRARIES
import pandas as pd #for dealing with csv import
import os # for joining paths and filenames sensibly
import numpy as np #for the population std
import glob # for finding csv data files
import platform # paths use different dividers on linux vs windows, so we need to test for this
import csv
from pandas.errors import EmptyDataError

# %%
# square_dot_game_new --> slow
# square_dot_game2_new --> fast
# monkey_game --> monkey

# %%
root_monkeys= 'C:\\Users\\david\\Downloads\\monkey2'
root_slow_SquareDot = 'C:\\Users\\david\\Downloads\\slow2'
root_fast_SquareDot2 = 'C:\\Users\\david\\Downloads\\fast2'

# %%
########################## monkey

folders_ = os.listdir(root_monkeys)
all_monkey_files = []

for idx,fold in enumerate(folders_):
    files = os.path.join(root_monkeys, folders_[idx])
    #search_string=os.path.join(files_,'*.csv') 
    files = glob.glob(files)
    all_monkey_files.append(files)
    

monkey_files = [item for sublist in all_monkey_files for item in sublist]


########################## slow

folders_ = os.listdir(root_slow_SquareDot)
all_slow_files = []

for idx,fold in enumerate(folders_):
    files = os.path.join(root_slow_SquareDot, folders_[idx])
    #search_string=os.path.join(files_,'*.csv') 
    files = glob.glob(files)
    all_slow_files.append(files)
    

slow_files = [item for sublist in all_slow_files for item in sublist]


############################## fast


folders_ = os.listdir(root_fast_SquareDot2)
all_fast_files = []

for idx,fold in enumerate(folders_):
    files = os.path.join(root_fast_SquareDot2, folders_[idx])
    #search_string=os.path.join(files_,'*.csv') 
    files = glob.glob(files)
    all_fast_files.append(files)
    

fast_files = [item for sublist in all_fast_files for item in sublist]




summary = []

# %% [markdown]
# ##### Monkey

# %%
frames = []
for filename in monkey_files:
    print(filename.split('\\')[-1])
    #import into python using pandas
    try:
        df = pd.read_csv(filename)
    except EmptyDataError:
        print('not enough data')
        print('')
        continue
    
    try:        
        df_sub = df[['Participant','mean_speed', 'max_speed', 'number_trials', 'number_trials_correct', 'valoracion_resp.keys']].iloc[-1]
        df_subset = pd.DataFrame(df_sub).transpose()
        frames.append(df_subset)
        print('ok')
        print('')
    
    except KeyError:
        print('KeyError - not stored')
        print('')
        continue
    
#######################################################################################################

df_ = pd.concat(frames)
df_ ['game'] = 'monkey'
df_=df_.rename(columns = {'valoracion_resp.keys':'valoracion'})

summary.append(df_)
# Out:
# daniel_BananaMonkey_2022_Oct_14_0947.csv
# KeyError - not stored
#
# dani_BananaMonkey_2022_Oct_14_0946.csv
# KeyError - not stored
#
# david_BananaMonkey_2022_Oct_12_2041.csv
# KeyError - not stored
#
# dgdg_BananaMonkey_2022_Oct_11_2153.csv
# KeyError - not stored
#
# er_BananaMonkey_2022_Oct_12_1358.csv
# KeyError - not stored
#
# esterita_BananaMonkey_2022_Oct_12_2022.csv
# KeyError - not stored
#
# ester_BananaMonkey_2022_Oct_11_2147.csv
# KeyError - not stored
#
# Ester_BananaMonkey_2022_Oct_12_2052.csv
# KeyError - not stored
#
# gf_BananaMonkey_2022_Oct_12_1210.csv
# KeyError - not stored
#
# gh_BananaMonkey_2022_Oct_12_1211.csv
# KeyError - not stored
#
# gh_BananaMonkey_2022_Oct_12_1332.csv
# KeyError - not stored
#
# grt_BananaMonkey_2022_Oct_12_1309.csv
# KeyError - not stored
#
# hh_BananaMonkey_2022_Oct_12_1351.csv
# KeyError - not stored
#
# hh_BananaMonkey_2022_Oct_12_2013.csv
# KeyError - not stored
#
# hh_BananaMonkey_2022_Oct_14_1843.csv
# KeyError - not stored
#
# hh_BananaMonkey_2022_Oct_15_1235.csv
# KeyError - not stored
#
# hh_BananaMonkey_2022_Oct_15_1242.csv
# KeyError - not stored
#
# hh_BananaMonkey_2022_Oct_15_1248.csv
# KeyError - not stored
#
# jaja_BananaMonkey_2022_Oct_15_1230.csv
# KeyError - not stored
#
# jeje_BananaMonkey_2022_Oct_12_1854.csv
# KeyError - not stored
#
# jeronimo_BananaMonkey_2022_Oct_16_1215.csv
# KeyError - not stored
#
# jh_BananaMonkey_2022_Oct_12_1230.csv
# KeyError - not stored
#
# jjj_BananaMonkey_2022_Oct_12_1338.csv
# KeyError - not stored
#
# jjk_BananaMonkey_2022_Oct_12_1345.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_12_1234.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_12_1245.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_12_1313.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_12_1314.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_12_1337.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_15_1241.csv
# KeyError - not stored
#
# jj_BananaMonkey_2022_Oct_15_1246.csv
# KeyError - not stored
#
# juju_BananaMonkey_2022_Oct_16_1437.csv
# ok
#
# juu_BananaMonkey_2022_Oct_12_1943.csv
# KeyError - not stored
#
# ju_BananaMonkey_2022_Oct_15_1253.csv
# KeyError - not stored
#
# kiki_BananaMonkey_2022_Oct_12_1228.csv
# KeyError - not stored
#
# ki_BananaMonkey_2022_Oct_11_2203.csv
# KeyError - not stored
#
# ki_BananaMonkey_2022_Oct_12_1233.csv
# KeyError - not stored
#
# ki_BananaMonkey_2022_Oct_12_1242.csv
# KeyError - not stored
#
# kjkj_BananaMonkey_2022_Oct_12_1222.csv
# KeyError - not stored
#
# kj_BananaMonkey_2022_Oct_12_1334.csv
# KeyError - not stored
#
# kj_BananaMonkey_2022_Oct_12_1922.csv
# KeyError - not stored
#
# kkk_BananaMonkey_2022_Oct_12_1921.csv
# KeyError - not stored
#
# kkk_BananaMonkey_2022_Oct_12_1959.csv
# KeyError - not stored
#
# kko_BananaMonkey_2022_Oct_13_1934.csv
# KeyError - not stored
#
# kk_BananaMonkey_2022_Oct_11_2154.csv
# KeyError - not stored
#
# kk_BananaMonkey_2022_Oct_12_1354.csv
# KeyError - not stored
#
# kk_BananaMonkey_2022_Oct_15_1245.csv
# KeyError - not stored
#
# kk_BananaMonkey_2022_Oct_15_1251.csv
# KeyError - not stored
#
# koko_BananaMonkey_2022_Oct_12_1928.csv
# KeyError - not stored
#
# koko_BananaMonkey_2022_Oct_15_1240.csv
# KeyError - not stored
#
# lilo_BananaMonkey_2022_Oct_11_2117.csv
# KeyError - not stored
#
# lilo_BananaMonkey_2022_Oct_14_1839.csv
# KeyError - not stored
#
# lilo_BananaMonkey_2022_Oct_16_1438.csv
# KeyError - not stored
#
# ll_BananaMonkey_2022_Oct_12_1346.csv
# KeyError - not stored
#
# lolo_BananaMonkey_2022_Oct_11_2059.csv
# KeyError - not stored
#
# lolo_BananaMonkey_2022_Oct_11_2125.csv
# KeyError - not stored
#
# lolo_BananaMonkey_2022_Oct_13_1839.csv
# KeyError - not stored
#
# loo_BananaMonkey_2022_Oct_12_1342.csv
# KeyError - not stored
#
# lorito_BananaMonkey_2022_Oct_15_1238.csv
# KeyError - not stored
#
# loro_BananaMonkey_2022_Oct_14_1751.csv
# KeyError - not stored
#
# loro_BananaMonkey_2022_Oct_15_1236.csv
# KeyError - not stored
#
# lo_BananaMonkey_2022_Oct_11_2152.csv
# KeyError - not stored
#
# lo_BananaMonkey_2022_Oct_12_1224.csv
# KeyError - not stored
#
# lo_BananaMonkey_2022_Oct_12_1239.csv
# KeyError - not stored
#
# lulo_BananaMonkey_2022_Oct_11_2100.csv
# KeyError - not stored
#
# lulu_BananaMonkey_2022_Oct_11_2141.csv
# KeyError - not stored
#
# mike_BananaMonkey_2022_Oct_16_1212.csv
# KeyError - not stored
#
# miky_BananaMonkey_2022_Oct_12_2012.csv
# KeyError - not stored
#
# monoo_BananaMonkey_2022_Oct_12_2046.csv
# KeyError - not stored
#
# monoo_BananaMonkey_2022_Oct_12_2047.csv
# KeyError - not stored
#
# nn_BananaMonkey_2022_Oct_15_1245.csv
# KeyError - not stored
#
# novia_BananaMonkey_2022_Oct_12_1326.csv
# KeyError - not stored
#
# nvbn_BananaMonkey_2022_Oct_13_1756.csv
# KeyError - not stored
#
# n_BananaMonkey_2022_Oct_12_1302.csv
# KeyError - not stored
#
# ool_BananaMonkey_2022_Oct_12_1900.csv
# KeyError - not stored
#
# oop_BananaMonkey_2022_Oct_12_1920.csv
# KeyError - not stored
#
# paco_BananaMonkey_2022_Oct_12_1953.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2022-10-18_17h49.21.876.csv
# ok
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h28.20.944.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h29.27.790.csv
# ok
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h29.36.967.csv
# ok
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h29.47.384.csv
# ok
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h31.31.558.csv
# ok
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h31.44.239.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2022-10-19_13h35.19.654.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-08_20h04.48.998.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h35.38.199.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h35.55.754.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h36.07.030.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h38.10.106.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h40.51.099.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h40.53.850.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h41.41.792.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h42.51.649.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_10h46.33.814.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_13h02.16.876.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_13h02.51.669.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_13h03.14.559.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_13h05.07.249.csv
# ok
#
# PARTICIPANT_BananaMonkey_2023-01-09_13h29.58.199.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2023-01-09_13h35.18.478.csv
# KeyError - not stored
#
# PARTICIPANT_BananaMonkey_2023-01
csv
# not enough data
#
# PARTICIPANT_monkey_game_2025-09-22_09h46.15.574.csv
# not enough data
#
# PARTICIPANT_monkey_game_2025-09-22_09h46.45.347.csv
# not enough data
#
# PARTICIPANT_monkey_game_2025-09-22_12h02.18.381.csv
# not enough data
#
# PARTICIPANT_monkey_game_2025-09-22_15h36.21.757.csv
# not enough data
#
# PARTICIPANT_monkey_game_2025-09-23_08h08.34.614.csv
# not enough data
#
# pepo_BananaMonkey_2022_Oct_11_2115.csv
# KeyError - not stored
#
# pero_BananaMonkey_2022_Oct_11_2149.csv
# KeyError - not stored
#
# poo_BananaMonkey_2022_Oct_12_1208.csv
# KeyError - not stored
#
# poo_BananaMonkey_2022_Oct_12_1335.csv
# KeyError - not stored
#
# poo_BananaMonkey_2022_Oct_12_1355.csv
# KeyError - not stored
#
# poo_BananaMonkey_2022_Oct_12_1849.csv
# KeyError - not stored
#
# poo_BananaMonkey_2022_Oct_12_1948.csv
# KeyError - not stored
#
# pop_BananaMonkey_2022_Oct_11_2201.csv
# KeyError - not stored
#
# po_BananaMonkey_2022_Oct_12_1322.csv
# KeyError - not stored
#
# ppp_BananaMonkey_2022_Oct_12_1356.csv
# KeyError - not stored
#
# pp_BananaMonkey_2022_Oct_15_1252.csv
# KeyError - not stored
#
# priii_BananaMonkey_2022_Oct_16_1433.csv
# KeyError - not stored
#
# re_BananaMonkey_2022_Oct_12_1212.csv
# KeyError - not stored
#
# re_BananaMonkey_2022_Oct_12_1225.csv
# KeyError - not stored
#
# re_BananaMonkey_2022_Oct_12_1902.csv
# KeyError - not stored
#
# roro_BananaMonkey_2022_Oct_14_1827.csv
# KeyError - not stored
#
# rr_BananaMonkey_2022_Oct_15_1250.csv
# KeyError - not stored
#
# rt_BananaMonkey_2022_Oct_15_1155.csv
# KeyError - not stored
#
# ruru_BananaMonkey_2022_Oct_12_1917.csv
# KeyError - not stored
#
# ru_BananaMonkey_2022_Oct_12_1325.csv
# KeyError - not stored
#
# ru_BananaMonkey_2022_Oct_12_1858.csv
# KeyError - not stored
#
# tt_BananaMonkey_2022_Oct_12_1216.csv
# KeyError - not stored
#
# update_BananaMonkey_2022_Oct_11_2158.csv
# KeyError - not stored
#
# upd_BananaMonkey_2022_Oct_14_1828.csv
# KeyError - not stored
#
# uuu_BananaMonkey_2022_Oct_12_1215.csv
# KeyError - not stored
#
# uu_BananaMonkey_2022_Oct_12_1852.csv
# KeyError - not stored
#
# _BananaMonkey_2022_Oct_12_1329.csv
# KeyError - not stored
#
# ññ_BananaMonkey_2022_Oct_12_1359.csv
# KeyError - not stored
#
# ññ_BananaMonkey_2022_Oct_15_1252.csv
# KeyError - not stored

# %% [markdown]
# ##### Slow

# %%
frames = []
for filename in slow_files:
    print(filename.split('\\')[-1])
    #import into python using pandas
    try:
        df = pd.read_csv(filename)
    except EmptyDataError:
        print('not enough data')
        print('')
        continue
    
    try:        
        df_sub = df[['Participant','mean_speed', 'max_speed', 'number_trials', 'number_trials_correct', 'key_resp_2.keys']].iloc[-1]
        df_subset = pd.DataFrame(df_sub).transpose()
        frames.append(df_subset)
        print('ok')
        print('')
    
    except KeyError:
        print('KeyError - not stored')
        print('')
        continue
            

        
    
#######################################################################################################

df_ = pd.concat(frames)
# %%
frames = []
for filename in fast_files:
    print(filename.split('\\')[-1])
    #import into python using pandas
    try:
        df = pd.read_csv(filename)
    except EmptyDataError:
        print('not enough data')
        print('')
        continue
    
    try:        
        df_sub = df[['Participant','mean_speed', 'max_speed', 'number_trials', 'number_trials_correct', 'key_resp_2.keys']].iloc[-1]
        df_subset = pd.DataFrame(df_sub).transpose()
        frames.append(df_subset)
        print('ok')
        print('')
    
    except KeyError:
        print('KeyError - not stored')
        print('')
        continue
            

        
    
#######################################################################################################

df_ = pd.concat(frames)
df_ ['game'] = 'fast'
df_=df_.rename(columns = {'key_resp_2.keys':'valoracion'})
summary.append(df_)
# Out:
# liron_BananaMonkey_2022_Oct_19_0018.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-18_17h55.32.955.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-18_23h48.26.429.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_10h28.52.746.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h28.18.990.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h28.47.261.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h29.28.720.csv
# KeyError - not stored
#
# PARTICIPANT_SquareDot2_2022-10-19_13h31.00.832.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h31.39.233.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h31.59.550.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h32.35.275.csv
# ok
#
# PARTICIPANT_SquareDot2_2022-10-19_13h33.45.320.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_10h35.47.726.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_10h36.10.340.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_10h37.20.645.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_10h38.06.520.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_10h38.16.396.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_13h02.22.632.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_13h03.17.134.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_13h05.39.125.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_13h29.20.659.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_14h23.28.510.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_16h23.50.828.csv
# KeyError - not stored
#
# PARTICIPANT_SquareDot2_2023-01-09_16h23.53.051.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_16h24.12.255.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-09_16h28.38.557.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h22.15.294.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h23.01.032.csv
# KeyError - not stored
#
# PARTICIPANT_SquareDot2_2023-01-10_10h23.06.650.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h23.32.404.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h23.50.526.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h24.03.635.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h24.15.818.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h25.19.690.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h26.57.668.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h27.22.782.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_10h29.01.136.csv
# KeyError - not stored
#
# PARTICIPANT_SquareDot2_2023-01-10_12h50.02.018.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_12h50.07.420.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_12h50.10.275.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_12h50.50.557.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_12h51.45.396.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_12h51.46.138.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_12h51.46.452.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_15h26.54.240.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_16h25.14.769.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_16h25.15.639.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_16h26.37.016.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-10_16h26.53.000.csv
# not enough data
#
# PARTICIPANT_SquareDot2_2023-01-10_16h28.20.905.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_10h23.07.783.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_10h23.56.131.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_10h23.57.965.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_10h26.36.494.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_10h27.33.489.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_10h27.44.522.csv
# KeyError - not stored
#
# PARTICIPANT_SquareDot2_2023-01-11_10h30.08.654.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h24.25.449.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h24.39.563.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h25.03.093.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h25.13.359.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h25.53.360.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h26.39.258.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h26.59.025.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-11_16h27.05.817.csv
# not enough data
#
# PARTICIPANT_SquareDot2_2023-01-11_16h30.07.668.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12_09h28.48.034.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12_09h28.48.195.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12_09h28.52.840.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12_09h28.56.643.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12_09h29.02.446.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12_09h29.04.127.csv
# ok
#
# PARTICIPANT_SquareDot2_2023-01-12
csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h31.40.884.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h31.47.640.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h32.48.997.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h33.19.683.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h34.25.174.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h34.27.625.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h34.34.309.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h34.58.874.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h35.11.823.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h35.19.039.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h35.26.709.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h36.11.395.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h36.17.667.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h36.56.668.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_09h37.02.169.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-13_12h06.10.624.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-14_10h48.25.295.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-22_13h56.13.948.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-03-22_15h12.12.380.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-04-13_15h36.35.989.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-04-13_15h36.43.593.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-04-13_15h36.54.339.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2023-05-04_15h12.04.480.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-13_13h09.12.045.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-14_08h04.35.450.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_09h44.03.699.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_09h44.19.343.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_09h44.37.248.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_09h44.45.707.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_09h44.50.963.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_11h18.47.127.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-02-15_11h23.47.331.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-04-09_10h59.43.873.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-05-27_11h22.53.625.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_15h16.38.206.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_18h44.42.898.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_18h45.08.571.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_18h46.21.226.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_18h47.01.928.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_18h47.15.170.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-10-17_18h47.19.951.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-12-04_07h48.36.273.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2024-12-04_08h58.48.465.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-01-24_11h50.06.760.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-18_08h39.10.633.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-18_11h18.06.875.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-18_11h22.30.065.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-21_21h55.00.768.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-24_10h53.26.360.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-25_12h17.40.947.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-02-25_12h19.04.900.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-01_12h27.36.080.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-03_12h15.42.263.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-03_12h16.34.154.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-04_09h49.33.298.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-04_09h50.38.632.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-04_10h14.55.969.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-04_10h47.57.315.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-04_12h17.51.653.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-04-04_12h27.42.727.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-09-22_12h02.53.983.csv
# not enough data
#
# PARTICIPANT_Square_dot_game2_new_2025-09-22_12h04.37.826.csv
# not enough data

# %% [markdown]
# ## PLOTS

# %%
import pandas as pd #for dealing with csv import
import matplotlib.pyplot as plt  # Matplotlib's pyplot: MATLAB-like syntax
import scipy
from scipy import stats
import numpy as np
import seaborn as sns

# %%
df = pd.concat(summary)
df['percentage_correct'] = df['number_trials_correct'] / df['number_trials']
df['time_played'] = df['mean_speed']*df['number_trials']*10
df['max_speed_correct'] = df['max_speed']*df['percentage_correct']
print(len(df))
df.head()
# Out:
# 1031
#                  Participant mean_speed max_speed number_trials  \
# 6                        NaN     0.0225     0.025           3.0
# 80                      Dani   0.071333     0.105          75.0
# 128         margaret/daniela   0.062083    0.0875         120.0
# 160  margaret.__________hugo   0.066083    0.0925         150.0
# 96   princessmargaret/marc.a   0.062083    0.0925          90.0
#
#     number_trials_correct valoracion    game percentage_correct time_played  \
# 6                     3.0        NaN  monkey                1.0       0.675
# 80                   65.0        5.0  monkey           0.866667        53.5
# 128                 100.0        4.0  monkey           0.833333        74.5
# 160                 126.0        5.0  monkey               0.84   99.124999
# 96                   72.0        5.0  monkey                0.8      55.875
#
#     max_speed_correct
# 6               0.025
# 80              0.091
# 128          0.072917
# 160            0.0777
# 96              0.074

# %%
c_monk = '#e59500'
c_slow= 'aquamarine' #'#002642'
c_fast = 'indianred' # '#840032'

sns.set_context("poster")

# %%
plt.figure(figsize=(25,8))

plt.subplot(131)
sns.barplot(x='game', y='number_trials', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.5)
#plt.yticks([0,0.5,1,1.5])
plt.ylabel('# trials')
plt.xlabel('')
plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
plt.title('Temps de joc', fontsize=30)


plt.subplot(132)
sns.barplot(x='game', y='max_speed_correct', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.)
#plt.yticks([0,0.25,0.5,0.75,1])
plt.ylabel('% correctes * velocitat màxima')
plt.xlabel('')
plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
plt.title('Aprenentatge', fontsize=30)

plt.subplot(133)
sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)   
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.5)
#plt.yticks([0,0.5,1,1.5])
plt.ylabel('punts')
plt.xlabel('')
plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
plt.title('Valoració', fontsize=30)

plt.tight_layout()
plt.subplots_adjust(wspace=0.3)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\1538227968.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='number_trials', order = ['monkey', 'slow', 'fast'],
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\1538227968.py:20: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='max_speed_correct', order = ['monkey', 'slow', 'fast'],
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\1538227968.py:35: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'],

# %%
# plt.figure(figsize=(25,8))

# plt.subplot(131)
# sns.barplot(x='game', y='number_trials', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('# trials')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Temps de joc', fontsize=30)


# plt.subplot(132)
# sns.barplot(x='game', y='max_speed', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('velocitat màxima')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.xlabel('')
# plt.title('Aprenentatge', fontsize=30)

# plt.subplot(133)
# sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)   
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('punts')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Valoració', fontsize=30)

# plt.tight_layout()
# plt.subplots_adjust(wspace=0.3)

# %%
# plt.figure(figsize=(25,8))

# plt.subplot(131)
# sns.barplot(x='game', y='time_played', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.sum, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('total segons')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Temps de joc', fontsize=30)


# plt.subplot(132)
# sns.barplot(x='game', y='percentage_correct', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# plt.ylim(0,1.)
# plt.yticks([0,0.25,0.5,0.75,1])
# plt.ylabel('% correctes')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Aprenentatge', fontsize=30)

# plt.subplot(133)
# sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)   
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('punts')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Valoració', fontsize=30)

# plt.tight_layout()
# plt.subplots_adjust(wspace=0.3)

# %%
# plt.figure(figsize=(25,8))

# plt.subplot(131)
# sns.barplot(x='game', y='number_trials', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('# trials')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Temps de joc', fontsize=30)


# plt.subplot(132)
# sns.barplot(x='game', y='percentage_correct', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# plt.ylim(0,1.)
# plt.yticks([0,0.25,0.5,0.75,1])
# plt.ylabel('% correctes')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Aprenentatge', fontsize=30)

# plt.subplot(133)
# sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'], 
#             palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
# plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
# plt.gca().spines['top'].set_visible(False)   
# plt.gca().get_xaxis().tick_bottom()                                                                                         
# plt.gca().get_yaxis().tick_left()
# plt.gca().tick_params(direction='in') #direction
# #plt.ylim(0,1.5)
# #plt.yticks([0,0.5,1,1.5])
# plt.ylabel('punts')
# plt.xlabel('')
# plt.xticks([0,1,2], ['flux', 'avorriment', 'frustració'])
# plt.title('Valoració', fontsize=30)

# plt.tight_layout()
# plt.subplots_adjust(wspace=0.3)

# %% [markdown]
# ## INDIVIDUAL PLOTS

# %%
sns.set_context("talk")

# %%
scipy.stats.ttest_ind
# Out:
# <function scipy.stats._stats_py.ttest_ind(a, b, axis=0, equal_var=True, nan_policy='propagate', permutations=None, random_state=None, alternative='two-sided', trim=0, *, keepdims=False)>

# %%
a=list(df.loc[df['game']=='monkey', 'number_trials'].values)

# %%
b=list(df.loc[df['game']=='slow', 'number_trials'].values)

# %%
scipy.stats.ttest_ind(a, b)
# Out:
# TtestResult(statistic=np.float64(16.721549166633284), pvalue=np.float64(4.630302205664322e-53), df=np.float64(700.0))

# %%
########### NUMBER OF TRIALS

plt.figure()
sns.barplot(x='game', y='number_trials', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.5)
#plt.yticks([0,0.5,1,1.5])
plt.ylabel('number of trials')
plt.xlabel('')
plt.xticks([0,1,2], ['flow', 'boring', 'frustrating'])
plt.show(block=False)


print('monkey-boring')
print(scipy.stats.ttest_ind( list(df.loc[df['game']=='monkey', 'number_trials'].values), list(df.loc[df['game']=='slow', 'number_trials'].values) ) ) 
print('')

print('monkey-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'number_trials'].values), list(df.loc[df['game']=='fast', 'number_trials'].values) ) )
print('')

print('boring-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='slow', 'number_trials'].values), list(df.loc[df['game']=='fast', 'number_trials'].values) ) )
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\3952704125.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='number_trials', order = ['monkey', 'slow', 'fast'],
# monkey-boring
# TtestResult(statistic=np.float64(16.721549166633284), pvalue=np.float64(4.630302205664322e-53), df=np.float64(700.0))
#
# monkey-frustrating
# TtestResult(statistic=np.float64(3.1915439943325326), pvalue=np.float64(0.001476882919346528), df=np.float64(717.0))
#
# boring-frustrating
# TtestResult(statistic=np.float64(-12.673061508355397), pvalue=np.float64(5.4133298697795084e-33), df=np.float64(639.0))

# %%
########### max_speed * correct

plt.figure()
sns.barplot(x='game', y='max_speed_correct', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.)
#plt.yticks([0,0.25,0.5,0.75,1])
plt.ylabel('% correct * max speed')
plt.xlabel('')
plt.xticks([0,1,2], ['flow', 'boring', 'frustrating'])
plt.show(block=False)



print('monkey-boring')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'max_speed_correct'].values), list(df.loc[df['game']=='slow', 'max_speed_correct'].values) ) )
print('')

print('monkey-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'max_speed_correct'].values), list(df.loc[df['game']=='fast', 'max_speed_correct'].values) ) )
print('')

print('boring-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='slow', 'max_speed_correct'].values), list(df.loc[df['game']=='fast', 'max_speed_correct'].values) ) )
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\2510829030.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='max_speed_correct', order = ['monkey', 'slow', 'fast'],
# monkey-boring
# TtestResult(statistic=np.float64(61.757514643024884), pvalue=np.float64(1.5988173740433892e-285), df=np.float64(700.0))
#
# monkey-frustrating
# TtestResult(statistic=np.float64(29.68262339595428), pvalue=np.float64(6.584346035691625e-127), df=np.float64(717.0))
#
# boring-frustrating
# TtestResult(statistic=np.float64(-22.300559654410222), pvalue=np.float64(6.357241500628583e-82), df=np.float64(639.0))

# %%
########### EVALUATION OF THE GAME

plt.figure()
sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.5)
#plt.yticks([0,0.5,1,1.5])
plt.ylabel('points evaluation')
plt.xlabel('')
plt.xticks([0,1,2], ['flow', 'boring', 'frustrating'])
plt.show(block=False)

print('monkey-boring')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'valoracion'].values), list(df.loc[df['game']=='slow', 'valoracion'].values) ) )
print('')

print('monkey-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'valoracion'].values), list(df.loc[df['game']=='fast', 'valoracion'].values) ) )
print('')

print('boring-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='slow', 'valoracion'].values), list(df.loc[df['game']=='fast', 'valoracion'].values) ) )
print('')
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\2555037289.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='valoracion', order = ['monkey', 'slow', 'fast'],
# monkey-boring
# TtestResult(statistic=np.float64(nan), pvalue=np.float64(nan), df=np.float64(nan))
#
# monkey-frustrating
# TtestResult(statistic=np.float64(nan), pvalue=np.float64(nan), df=np.float64(nan))
#
# boring-frustrating
# TtestResult(statistic=np.float64(nan), pvalue=np.float64(nan), df=np.float64(nan))

# %%
########### SPEED
plt.figure()
sns.barplot(x='game', y='max_speed', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
#plt.ylim(0,1.5)
#plt.yticks([0,0.5,1,1.5])
plt.ylabel('velocitat màxima')
plt.xlabel('')
plt.xticks([0,1,2], ['flow', 'boring', 'frustrating'])
plt.show(block=False)


print('monkey-boring')
print(scipy.stats.ttest_ind( list(df.loc[df['game']=='monkey', 'max_speed'].values), list(df.loc[df['game']=='slow', 'max_speed'].values) ) ) 
print('')

print('monkey-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'max_speed'].values), list(df.loc[df['game']=='fast', 'max_speed'].values) ) )
print('')

print('boring-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='slow', 'max_speed'].values), list(df.loc[df['game']=='fast', 'max_speed'].values) ) )
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\4144968275.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='max_speed', order = ['monkey', 'slow', 'fast'],
# monkey-boring
# TtestResult(statistic=np.float64(64.24511394388537), pvalue=np.float64(9.924794289288538e-296), df=np.float64(700.0))
#
# monkey-frustrating
# TtestResult(statistic=np.float64(-7.727881223961734), pvalue=np.float64(3.69740618944354e-14), df=np.float64(717.0))
#
# boring-frustrating
# TtestResult(statistic=np.float64(-45.755789043710614), pvalue=np.float64(8.482439478702966e-204), df=np.float64(639.0))

# %%
########### PERCENTAGE OF CORRECT

plt.figure()
sns.barplot(x='game', y='percentage_correct', order = ['monkey', 'slow', 'fast'], 
            palette=[c_monk, c_slow, c_fast], ci=68, estimator=np.mean, data=df)
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylim(0,1.)
plt.yticks([0,0.25,0.5,0.75,1])
plt.ylabel('% of correct')
plt.xlabel('')
plt.xticks([0,1,2], ['flow', 'boring', 'frustrating'])
plt.show(block=False)



print('monkey-boring')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'percentage_correct'].values), list(df.loc[df['game']=='slow', 'percentage_correct'].values) ) )
print('')

print('monkey-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='monkey', 'percentage_correct'].values), list(df.loc[df['game']=='fast', 'percentage_correct'].values) ) )
print('')

print('boring-frustrating')
print(scipy.stats.ttest_ind(list(df.loc[df['game']=='slow', 'percentage_correct'].values), list(df.loc[df['game']=='fast', 'percentage_correct'].values) ) )
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_26320\1558043327.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='game', y='percentage_correct', order = ['monkey', 'slow', 'fast'],
# monkey-boring
# TtestResult(statistic=np.float64(-22.17460764832784), pvalue=np.float64(6.234304698176183e-83), df=np.float64(700.0))
#
# monkey-frustrating
# TtestResult(statistic=np.float64(35.41671600333298), pvalue=np.float64(1.2681386071472124e-159), df=np.float64(717.0))
#
# boring-frustrating
# TtestResult(statistic=np.float64(38.38143864552859), pvalue=np.float64(4.852063419270353e-168), df=np.float64(639.0))
